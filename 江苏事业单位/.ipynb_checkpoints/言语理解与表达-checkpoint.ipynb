# %% [markdown]
# <h3><a href='#mailuo'>1.行文脉络</a></h3>
# <h3><a href='#logic'>2.逻辑关系（对应关系，包容关系）</a></h3>
# <h3><a href='#data'>3.资料分析（简单计算，直接找数，排序类）</a></h3>
# <h3><a href='#order'>4.语句排序</a></h3>
# <h3><a href='#tiankong'>5.逻辑填空</a></h3>

# %% [markdown]
# <h3><a name='mailuo'>1.行文脉络</a></h3>

# %% [markdown]
# #### 行文脉络（总分/分总/总分总）
# - 【理论要点】 把握中心句，分述句的特点
# - 【中心句特征】 结论/对策/观点
# - 【分述句特征】
#     - 调查报告、数据资料等
#     - 举例子
#     - 原因解释：由于...;因为...
#     - 正反论证
#     - 并列分述：例+例+例；例+原因+正反；主体...主体...

# %% [markdown]
# -----

# %% [markdown]
# <h3><a name='logic'>2.逻辑关系（对应关系，包容关系）</a></h3>

# %% [markdown]
# 。。。。。

# %% [markdown]
# 。。。。。

# %% [markdown]
# （单选题）发动机：飞机：旅客 （）
# - A 琴键：钢琴：音乐
# - B 电池：手电筒：灯光
# - C 发条：钟表：时间
# - D 杆秤：秤杆：重量

# %% [markdown]
# 答案解析：
# - 第一步：判断题干词语间的逻辑关系。
#     - 发动机 是 飞机 的组成部分，且是 飞机 的动力来源装置，飞机通过运载 乘客 实现其功能
# - 第二步：判断选项词语间的逻辑关系。
#     - 琴键 是 钢琴 的组成部分，但是 琴键 不是飞机的 动力来源装置，排除
#     - 电池 并非是 手电筒的组成部分，而是 配套关系 的对应，排除（第一次做错误地将其认为是动力来源）
#     - 发条 是 钟表 的组成部分，也是 钟表 的动力来源装置，钟表通过计算 时间 实现其功能
#     - 秤杆 是 杆秤 的组成部分，但词语顺序不一致。排除
#
# 正确答案为C。

# %% [markdown]
# （单选题）桎梏：刑具：束缚（）
# - A 月光：月亮：皎洁
# - B 曙光：阳光：希望
# - C 兄弟：手足：友谊
# - D 危机：风险：突发

# %% [markdown]
# 答案解析：
# - 第一步：判断题干词语间的逻辑关系。
#     - 桎梏 是中国古代的一种刑具，在手上戴的为梏，在脚上戴的为桎，可以象征束缚。前两者是 种属关系，第一个词和第三个是为 喻象征义。
# - 第二步：判断选项词语间的逻辑关系。
#     - 月光不是月亮，不是种属关系，排除
#     - 曙光是破晓时的阳光，用来比喻希望。曙光属于阳光的一种，象征希望。正确
#     - 兄弟比喻成手足，不是种属关系，排除
#     - 危机具有风险性和突发性，后两个词与第一个词是属性对应，排除。
#
# 正确答案为B

# %% [markdown]
# ----

# %% [markdown]
# <h3><a name='data'>3.资料分析（简单计算，直接找数，排序类）</a></h3>

# %% [markdown]
# 注意坑：
# - 时间
#     - 时间点、时间段、同比/环比
# - 单位
#     - 亿/万亿，%/千分之一，元/美元
# - 方向
#     - 最多/最少，从高到低/从低到高，高于/低于

# %% [markdown]
# （单选题）2015年1-10月份，第三产业中，基础设施投资（不含电力）79510亿元，同比增长17.4%，增速比1-9月份回落0.7个百分点。其中，水利管理业投资增长23%，增速提高0.5个百分点；公共设施管理业投资增长19.4%，增速回落0.6个百分点；道路运输业投资增长17.7%，增速回落0.4个百分点；铁路运输业投资增长1.4%，增速回落0.4个百分点。

# %% [markdown]
# 2015年1-9月份第三产业的基础设施投资（不含电力）中，下列项目同比增速从大到小排序正确的是（）
# - A 水利管理业投资，公共设施管理业投资，道路运输业投资，铁路运输业投资
# - B 铁路运输业投资，道路运输业投资，公共设施管理业投资，水利管理业投资
# - C 水利管理业投资，道路运输业投资，公共设施管理业投资，铁路运输业投资
# - D 铁路运输业投资，公共设施管理业投资，道路运输业投资，水利管理业投资

# %% [markdown]
# 题目解析：！！！
# - 注意：材料提供的是1-10月份的，题目中问的是1-9月份的。
# - 10月份的同比增长17.4%，较1-9月份回落0.7，即1-9月份的同比增长为 （17.4+0.7）%。
#     - 以此类推：
#         - 水利：（23-0.5）=22.5%
#         - 公共：（19.4+0.6）=20%
#         - 道路：（17.7+0.4）=18.1%
#         - 铁路：（1.4+0.4）=1.8%
#
# 正确答案选A。
# 虽然哪怕审题错误也不会影响答案，但是这个是对于我个人的材料题的盲区的解惑。

# %% [markdown]
# ----

# %% [markdown]
# <h3><a name='order'>4.语句排序</a></h3>

# %% [markdown]
# 提问方式：
# 将以上几个句子重新排列，语序正确的是...

# %% [markdown]
# <img src='./images/010.png' width=300></img>

# %% [markdown]
# 理论要点：
# - 对比选项，确定首句
# - 确定捆绑集团/确定顺序/确定尾句
# - 验证

# %% [markdown]
# **确定首句**：
# - 适合做首句
#     - 背景引入
#         - 随着，近年来，在...大背景/大环境下，长期以来
#     - 下定义
#         - ...是，被称为...
#         - ...就是/是指
#     - 提出观点
#         - 有人说，人们普遍认为
# - 不适合做首句
#     - 关联词后半部分，指代词，由“如”引导的例子

# %% [markdown]
# **确定捆绑**：
# - 关联词捆绑
#     - 配套出现（不但，而且）
#     - 单独一个（但，同时，分析句子意思）
# - 指代词捆绑
#     - 这，那，他，该，其
# - 共同信息捆绑
#     - 着特殊信息捆绑

# %% [markdown]
# （单选题）①魏晋时期是书家辈出的时代
# ②尺牍之迹因书法而重于世的情况越来越普遍
# ③许多书家都擅长尺牍之学
# ④魏晋时期，“工尺牍”和“善书”被视为值得称道的修养和才能，二者关系密切
# ⑤书家写的尺牍尤其具有收藏价值
# ⑥这种情况在魏晋以来的史籍里得到反映，比如“言书法则不离尺牍”
# 将以上6个句子重新排列，语序正确的是：  （）
# - A 1，3，4，2，5，6
# - B 2，3，5，1，6，4
# - C 3，4，5，6，1，2
# - D 4，6，1，3，2，5

# %% [markdown]
# 答案解析：
# - 观察选项，首句不易判断，四句话都可以作为首句特征。
# - 再观察句子，6⃣️句中，出现“这种情况”，考虑 **指代词捆绑**，6⃣️句中的举例“言书法则不离尺牍”，强调二者关系的密切，4⃣️句也强调二者关系的密切，故4⃣️6⃣️捆绑，选择D项。

# %% [markdown]
# 说实话，这题我觉得每句话都挺恶心，完全靠4⃣️6⃣️捆绑。即使是D项。也不是完全通顺的感觉。

# %% [markdown]
# （单选题）将下面5个句子重新排列，语序正确的是（  ）。
# ①商代以后，随着文字的出现，书写需求增加，周宣王时期“刑夷始制墨”，出现了颗粒状人工墨
# ②到了以彩陶为典型特征的仰韶文化时期，已经有了用来研墨颜料的研磨器——石研
# ③这些长过半米的大石器，是用来加工粮食的
# ④砚起源于研磨器，目前已知最早的研磨器是距今七、八千年的裴李岗、磁山文化时期的石磨盘和石磨棒
# ⑤此后，用于研磨的石研，就成为早期的砚

# %% [markdown]
# - A 1，3，4，5，2
# - B 4，3，2，1，5
# - C 1，3，4，2，5
# - D 4，3，2，5，1

# %% [markdown]
# 答案解析：

# %% [markdown]
# - 从选项入手，首句不好判定
# - 3⃣️句中出现 代词”这“，”这些...大石器”指代4⃣️句中的“石磨盘和石磨棒”，排除AC。
# - 对比BD两项，不同之处在于1⃣️5⃣️的顺序，1⃣️句讲的是出现了墨，5⃣️句讲的是出现了砚，按照先后顺序，应该先有墨，才有研墨的砚，所以1⃣️5⃣️相连。

# %% [markdown]
# 从上面两道题可以看出，如果实在通读不符合语感，则通过方法论来判断。

# %% [markdown]
# （单选题）
# ①作为新兴的农村商业中心，市镇并不以政治中心为依托，而是基于商业和市场活动兴起，又以商品经济体的形式发展，因而具有鲜明的经济中心的特征
# ②就发展趋向而言，由于较少地受到政治因素的控制和干扰，市镇有着较州县城市更大的自主发展空间
# ③相对于传统州县城市的转型，两宋时期各种形式的市镇大量涌现，在某种程度上有着更值得关注的文明意义
# ④可以说，市镇的广泛兴起和发展，既是城市文明向广大农村扩散的反映，也是乡村社会自我调整与变革的结果
# ⑤从起初简单的商品交易和流通活动到较为完整的商品经济体系，从聚散不定的村落交易点到初具专业化的商贸聚合地，从形式单一的乡村聚落到结构复杂的商业社区，市镇立足于乡村社会而又逐渐超越乡村文明，成为一种正在形成中的新兴经济都市形态
# ⑥据不完全统计，两宋时期各地先后兴起的市镇，迄今尚有史可考的就超过了3600处
#
#
# 将以上6个句子重新排列，语序正确的是：
# - A 3，6，1，2，5，4
# - B 1，4，2，6，3，5
# - C 5，6，1，2，4，3
# - D 4，3，5，6，1，2

# %% [markdown]
# 答案解析：
# - 首句不好判断
# - 只有3⃣️和6⃣️出现了特殊信息“两宋时期”，且均在谈论两宋时期市镇的情况，故3⃣️6⃣️捆绑，排除CD选项
# - 确定尾句，4⃣️中的“可以说”总结前文，5⃣️讲述市镇称为经济都市形态的发展过程，对比4⃣️吴，4⃣️总结前文更适合做尾句，排除B项。

# %% [markdown]
# ----

# %% [markdown]
# <h3><a name='tiankong'>5.逻辑填空</a></h3>

# %% [markdown]
# - **转折**
#     - 标识词
#         - 但是，然而，却...
#     - 理论要点
#         - 前后语义相反
# - **递进**
#     - 标识词
#         - 而且、甚至、更...
#     - 理论要点
#         - 语义程度前轻后重

# %% [markdown]
# - 关联关系：**并列**
#     - 理论要点：
#         - 同义并列：顿号（、），逗号（，）
#             - 如：面对反腐，我们要有踏石留印、抓铁有痕的决心。
#         - 反义并列：不是...而是...,是...不是...,相反，反之...
#             - 如：乐观的人...,反之，悲观的人...

# %% [markdown]
# 例题：
# 目前，我国不少大城市已处于超载状态，“城市病”严重，而人口还在不断 ________ ，许多中小城市和小城镇发展缓慢，甚至出现 ________ ，对农名工失去吸引力。面对这一现状和城镇化所带来的巨大压力，城市群的发展被寄予厚望。
# - A 增加 空置
# - B 迁移 停滞
# - C 涌入 萎缩
# - D 流动  退化

# %% [markdown]
# 答案解析： 选C
# - 根据超载状态，排除BD
# - 根据发展缓慢，递进关系，选择C
